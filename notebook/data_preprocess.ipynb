# %%
import pandas as pd
import numpy as np
import missingno as msno
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']

# %%
DATA_DIR = '../data/data_2015_2021.csv'

# %%
data = pd.read_csv(DATA_DIR)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 17 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Source.Name  1048575 non-null  object
#  1   date         1048574 non-null  float64
#  2   hour         1048574 non-null  float64
#  3   type         1048574 non-null  object
#  4   北京           918262 non-null   float64
#  5   天津           924873 non-null   float64
#  6   石家庄          925757 non-null   float64
#  7   唐山           925630 non-null   float64
#  8   秦皇岛          925198 non-null   float64
#  9   邯郸           925747 non-null   float64
#  10  保定           925801 non-null   float64
#  11  张家口          924604 non-null   float64
#  12  承德           925671 non-null   float64
#  13  廊坊           925046 non-null   float64
#  14  沧州           925194 non-null   float64
#  15  衡水           924648 non-null   float64
#  16  邢台           925629 non-null   float64
# dtypes: float64(15), object(2)
# memory usage: 136.0+ MB

# %%
data = data.iloc[:-1,:]

# %%
data = data[::-1]

# %%
data = data.reset_index(drop = True).dropna(thresh = 5,axis=0)

# %%
# data.to_csv('../data/data.csv',index=False)

# %%
msno.matrix(data)
# Out:
# <AxesSubplot:>

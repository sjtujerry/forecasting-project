# %%
import pandas as pd
import numpy as np

# %%
DATA_DIR = '../data/data.csv'
df = pd.read_csv(DATA_DIR)

# %%
df
# Out:
#         Unnamed: 0                Source.Name        date  hour       type  \
# 0                0  china_cities_20150102.csv  20150102.0  23.0     CO_24h
# 1                1  china_cities_20150102.csv  20150102.0  23.0         CO
# 2                2  china_cities_20150102.csv  20150102.0  23.0  O3_8h_24h
# 3                3  china_cities_20150102.csv  20150102.0  23.0      O3_8h
# 4                4  china_cities_20150102.csv  20150102.0  23.0     O3_24h
# ...            ...                        ...         ...   ...        ...
# 926248      926248  china_cities_20220402.csv  20220402.0   0.0   PM10_24h
# 926249      926249  china_cities_20220402.csv  20220402.0   0.0       PM10
# 926250      926250  china_cities_20220402.csv  20220402.0   0.0  PM2.5_24h
# 926251      926251  china_cities_20220402.csv  20220402.0   0.0      PM2.5
# 926252      926252  china_cities_20220402.csv  20220402.0   0.0        AQI
#
# ...
